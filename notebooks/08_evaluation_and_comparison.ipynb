# %% [markdown]
# # Final evaluation (test season)
#
# Single-use evaluation on the held-out test season + sliced metrics.

# %%
import os, sys
os.environ.setdefault('OMP_NUM_THREADS', '4')
sys.path.insert(0, os.path.abspath('..'))
from src.seeds import set_global_seed
set_global_seed(42)
from src.config import get_config
cfg = get_config()

# %%
import subprocess; subprocess.run([sys.executable,'-m','src.models.evaluate','--test'],cwd='..',check=True)

# %% [markdown]
# **Acceptance:** test read once; delta over baseline reported with sign.

# %%
import json
r=json.load(open('../reports/figures/final_metrics.json'))
print('test AUC',round(r['test']['auc'],4),'delta',r['auc_delta_over_baseline'])

# %%
from IPython.display import Image, display
from pathlib import Path
p = Path('..') / 'reports/figures/final_reliability.png'
display(Image(str(p))) if p.exists() else print('(figure pending)')
