# %% [markdown]
# # Data acquisition (Tier A)
#
# Pull the in-scope shot spine into `data/raw/` and record a manifest.

# %%
import os, sys
os.environ.setdefault('OMP_NUM_THREADS', '4')
sys.path.insert(0, os.path.abspath('..'))
from src.seeds import set_global_seed
set_global_seed(42)
from src.config import get_config
cfg = get_config()

# %%
import subprocess; subprocess.run([sys.executable,'-m','src.data.acquire'],cwd='..',check=True)

# %% [markdown]
# **Acceptance:** >800k shots, no out-of-scope season.

# %%
import json
m=json.load(open('../data/raw/_manifest.json'))
print(m['rows'],'shots', m['seasons'])
assert m['rows']>800000
