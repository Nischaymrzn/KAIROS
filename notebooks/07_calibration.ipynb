# %% [markdown]
# # Calibration
#
# Make probabilities honest: isotonic vs Platt on validation.

# %%
import os, sys
os.environ.setdefault('OMP_NUM_THREADS', '4')
sys.path.insert(0, os.path.abspath('..'))
from src.seeds import set_global_seed
set_global_seed(42)
from src.config import get_config
cfg = get_config()

# %%
import subprocess; subprocess.run([sys.executable,'-m','src.models.calibrate'],cwd='..',check=True)

# %% [markdown]
# **Acceptance:** calibrated Brier <= uncalibrated Brier on validation.

# %%
from IPython.display import Image, display
from pathlib import Path
p = Path('..') / 'reports/figures/calibration_reliability.png'
display(Image(str(p))) if p.exists() else print('(figure pending)')
