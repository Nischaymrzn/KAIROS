# %% [markdown]
# # Cleaning and merge
#
# Clean the spine, derive the target, drop duplicates, merge enrichment.

# %%
import os, sys
os.environ.setdefault('OMP_NUM_THREADS', '4')
sys.path.insert(0, os.path.abspath('..'))
from src.seeds import set_global_seed
set_global_seed(42)
from src.config import get_config
cfg = get_config()

# %%
import subprocess; subprocess.run([sys.executable,'-m','src.features.build'],cwd='..',check=True)

# %% [markdown]
# **Acceptance:** binary target, no duplicate shot rows.

# %%
import pandas as pd
df=pd.read_parquet('../data/interim/shots_merged.parquet')
print(len(df),'rows'); assert df['MADE'].isin([0,1]).all()
